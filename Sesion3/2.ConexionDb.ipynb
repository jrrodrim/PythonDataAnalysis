# %%
#pip install "pymongo[srv]"
# Out:
#   Cell In[4], line 2
#     pip install sqlalchemy
#         ^
# SyntaxError: invalid syntax

# %%
pip install sqlalchemy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 34.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 28.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysqlclient
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.7-cp312-cp312-linux_x86_64.whl size=136732 sha256=116afa0b6d1daca382ace4a1a68776f45f3a88c5be124fcd2b605ab75565c075
#   Stored in directory: /home/codespace/.cache/pip/wheels/27/95/18/7f176fffd46629e710c04c810b9c4d7d4358fe7c96a7d2306d
# Successfully built mysqlclient
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy as db
from sqlalchemy import text
import pandas as pd

# %%
engine= db.create_engine("mysql://root:root@127.0.0.1:3310/retail_db")
conn= engine.connect()

# %%
#Conection database

customers_df=pd.read_sql_query("select * from customers",con=conn)
customers_df
# Out:
#        customer_id customer_fname customer_lname customer_email  \
# 0                1        Richard      Hernandez      XXXXXXXXX
# 1                2           Mary        Barrett      XXXXXXXXX
# 2                3            Ann          Smith      XXXXXXXXX
# 3                4           Mary          Jones      XXXXXXXXX
# 4                5         Robert         Hudson      XXXXXXXXX
# ...            ...            ...            ...            ...
# 12430        12431           Mary           Rios      XXXXXXXXX
# 12431        12432         Angela          Smith      XXXXXXXXX
# 12432        12433       Benjamin         Garcia      XXXXXXXXX
# 12433        12434           Mary          Mills      XXXXXXXXX
# 12434        12435          Laura         Horton      XXXXXXXXX
#
#       customer_password             customer_street customer_city  \
# 0             XXXXXXXXX          6303 Heather Plaza   Brownsville
# ...

# %%
#Conection database aother to read tables

Connection_df_2= pd.read_sql_table('categories', engine)
Connection_df_2
# Out:
#     category_id  category_department_id         category_name
# 0             1                       2              Football
# 1             2                       2                Soccer
# 2             3                       2   Baseball & Softball
# 3             4                       2            Basketball
# 4             5                       2              Lacrosse
# 5             6                       2      Tennis & Racquet
# 6             7                       2                Hockey
# 7             8                       2           More Sports
# 8             9                       3      Cardio Equipment
# 9            10                       3     Strength Training
# 10           11                       3   Fitness Accessories
# 11           12                       3          Boxing & MMA
# 12           13                       3           Electronics
# 13           14                       3        Yoga & Pilates
# ...

# %%
#Mongo Connection

from pymongo import MongoClient
#from pymongo.server_api import ServerApi

conn_string = "mongodb+srv://jaimer8906:VVDCqrtKOokE2ykt@cluster0.qjgyf.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client= MongoClient(conn_string)

client['sample_mflix']
# Out:
# Database(MongoClient(host=['cluster0-shard-00-02.qjgyf.mongodb.net:27017', 'cluster0-shard-00-01.qjgyf.mongodb.net:27017', 'cluster0-shard-00-00.qjgyf.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-7gymtm-shard-0', tls=True), 'sample_mflix')

# %%
#Collection para query a base de datos
collection= client['sample_mflix']['movies']
cursor_mongo = collection.find({})
df= pd.DataFrame(cursor_mongo)
df
# Out:
#                             _id  \
# 0      573a1390f29313caabcd42e8
# 1      573a1390f29313caabcd446f
# 2      573a1390f29313caabcd4803
# 3      573a1390f29313caabcd4eaf
# 4      573a1390f29313caabcd50e5
# ...                         ...
# 21344  573a13faf29313caabded1d6
# 21345  573a13faf29313caabded406
# 21346  573a13fbf29313caabdedf30
# 21347  573a13fbf29313caabdedf31
# 21348  573a13fbf29313caabdee03b
#
#                                                     plot  \
# 0      A group of bandits stage a brazen train hold-u...
# 1      A greedy tycoon decides, on a whim, to corner ...
# 2      Cartoon figures announce, via comic strip ball...
# 3      A woman, with the aid of her police officer sw...
# 4      The cartoonist, Winsor McCay, brings the Dinos...
# ...                                                  ...
# 21344  A-Gu enlists a group of contract killers in th...
# 21345  Karol, an ordinary young man, runs into a much...
# ...
